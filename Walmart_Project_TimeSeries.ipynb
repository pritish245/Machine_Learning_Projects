# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_new=pd.read_csv('Walmart (1).csv')
data_new
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
data_new.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
data_new.tail()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
data_new.shape
# Out:
# (6435, 8)

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
data_new['Date']=pd.to_datetime(data_new['Date'],format='%d-%m-%Y')

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
data_new.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
data_new.duplicated().sum()
# Out:
# 0

# %%
unemployment_correlation = data_new.groupby('Store')[['Weekly_Sales', 'Unemployment']].corr().unstack().iloc[:, 1]
print("\nCorrelation between Weekly Sales and Unemployment for each store:\n", unemployment_correlation)
# Out:
# Correlation between Weekly Sales and Unemployment for each store:
#  Store
# 1    -0.097955
# 2     0.066325
# 3    -0.230413
# 4    -0.337015
# 5    -0.207043
# 6     0.044251
# 7    -0.165382
# 8    -0.052580
# 9    -0.191534
# 10    0.131908
# 11   -0.020339
# 12   -0.009286
# 13   -0.171633
# 14    0.210786
# 15    0.078905
# 16   -0.070864
# 17   -0.263600
# 18    0.139179
# 19    0.101464
# 20   -0.095341
# 21    0.218367
# 22    0.039043
# 23   -0.077169
# 24   -0.012261
# 25   -0.004958
# 26   -0.066899
# 27   -0.014275
# 28    0.136671
# 29    0.084682
# 30    0.201862
# 31   -0.064738
# 32   -0.099455
# 33    0.101175
# 34    0.017010
# 35    0.483865
# 36    0.833734
# 37   -0.221287
# 38   -0.785290
# 39   -0.384681
# 40   -0.112528
# 41   -0.350630
# 42   -0.356355
# 43   -0.201954
# 44   -0.780076
# 45   -0.004041
# Name: (Weekly_Sales, Unemployment), dtype: float64

# %%
most_affected_stores = unemployment_correlation.sort_values().head(5)
print("\nStores most affected by Unemployment:\n", most_affected_stores)
# Out:
# Stores most affected by Unemployment:
#  Store
# 38   -0.785290
# 44   -0.780076
# 39   -0.384681
# 42   -0.356355
# 41   -0.350630
# Name: (Weekly_Sales, Unemployment), dtype: float64

# %%
holiday_impact = data_new.groupby('Holiday_Flag')['Weekly_Sales'].mean()
print("\nImpact of Holiday Flag on Weekly Sales:\n", holiday_impact)
# Out:
# Impact of Holiday Flag on Weekly Sales:
#  Holiday_Flag
# 0    1.041256e+06
# 1    1.122888e+06
# Name: Weekly_Sales, dtype: float64

# %%
temperature_correlation = data_new['Weekly_Sales'].corr(data_new['Temperature'])
print("\nCorrelation between Weekly Sales and Temperature:", temperature_correlation)
# Out:
# Correlation between Weekly Sales and Temperature: -0.06381001317946962

# %%
cpi_correlation = data_new['Weekly_Sales'].corr(data_new['CPI'])
print("\nCorrelation between Weekly Sales and CPI:", cpi_correlation)
# Out:
# Correlation between Weekly Sales and CPI: -0.07263416204017645

# %%
total_sales_per_store = data_new.groupby('Store')['Weekly_Sales'].sum()
top_stores = total_sales_per_store.sort_values(ascending=False).head(5)
print("\nTop Performing Stores:\n", top_stores)
# Out:
# Top Performing Stores:
#  Store
# 20    3.013978e+08
# 4     2.995440e+08
# 14    2.889999e+08
# 13    2.865177e+08
# 2     2.753824e+08
# Name: Weekly_Sales, dtype: float64

# %%
worst_store = total_sales_per_store.sort_values().head(1)
print("\nWorst Performing Store:\n", worst_store)

highest_sales = total_sales_per_store.max()
lowest_sales = total_sales_per_store.min()
sales_difference = highest_sales - lowest_sales
percentage_difference = (sales_difference / highest_sales) * 100

print("\nDifference between highest and lowest performing stores: ", sales_difference)
print("Percentage Difference: ", percentage_difference, "%")
# Out:
# Worst Performing Store:
#  Store
# 33    37160221.96
# Name: Weekly_Sales, dtype: float64
#
# Difference between highest and lowest performing stores:  264237570.49999997
# Percentage Difference:  87.67070533042084 %

# %%
data=pd.read_csv('Walmart (1).csv')
data
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
data.tail()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
data.shape
# Out:
# (6435, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
data['Date']=pd.to_datetime(data['Date'],format='%d-%m-%Y')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
data.drop(columns=['Holiday_Flag','Temperature','Fuel_Price','CPI','Unemployment'],inplace=True)

# %%
df1=pd.DataFrame(data[data['Store']==1])
df1
# Out:
#      Store       Date  Weekly_Sales
# 0        1 2010-02-05    1643690.90
# 1        1 2010-02-12    1641957.44
# 2        1 2010-02-19    1611968.17
# 3        1 2010-02-26    1409727.59
# 4        1 2010-03-05    1554806.68
# ..     ...        ...           ...
# 138      1 2012-09-28    1437059.26
# 139      1 2012-10-05    1670785.97
# 140      1 2012-10-12    1573072.81
# 141      1 2012-10-19    1508068.77
# 142      1 2012-10-26    1493659.74
#
# [143 rows x 3 columns]

# %%
df1.drop(columns=['Store'],inplace=True)
df1
# Out:
#           Date  Weekly_Sales
# 0   2010-02-05    1643690.90
# 1   2010-02-12    1641957.44
# 2   2010-02-19    1611968.17
# 3   2010-02-26    1409727.59
# 4   2010-03-05    1554806.68
# ..         ...           ...
# 138 2012-09-28    1437059.26
# 139 2012-10-05    1670785.97
# 140 2012-10-12    1573072.81
# 141 2012-10-19    1508068.77
# 142 2012-10-26    1493659.74
#
# [143 rows x 2 columns]

# %%
df1.set_index('Date',inplace=True)
df1
# Out:
#             Weekly_Sales
# Date
# 2010-02-05    1643690.90
# 2010-02-12    1641957.44
# 2010-02-19    1611968.17
# 2010-02-26    1409727.59
# 2010-03-05    1554806.68
# ...                  ...
# 2012-09-28    1437059.26
# 2012-10-05    1670785.97
# 2012-10-12    1573072.81
# 2012-10-19    1508068.77
# 2012-10-26    1493659.74
#
# [143 rows x 1 columns]

# %%
df1.index.name=None
df1
# Out:
#             Weekly_Sales
# 2010-02-05    1643690.90
# 2010-02-12    1641957.44
# 2010-02-19    1611968.17
# 2010-02-26    1409727.59
# 2010-03-05    1554806.68
# ...                  ...
# 2012-09-28    1437059.26
# 2012-10-05    1670785.97
# 2012-10-12    1573072.81
# 2012-10-19    1508068.77
# 2012-10-26    1493659.74
#
# [143 rows x 1 columns]

# %%
df1.head(13)
# Out:
#             Weekly_Sales
# 2010-02-05    1643690.90
# 2010-02-12    1641957.44
# 2010-02-19    1611968.17
# 2010-02-26    1409727.59
# 2010-03-05    1554806.68
# 2010-03-12    1439541.59
# 2010-03-19    1472515.79
# 2010-03-26    1404429.92
# 2010-04-02    1594968.28
# 2010-04-09    1545418.53
# 2010-04-16    1466058.28
# 2010-04-23    1391256.12
# 2010-04-30    1425100.71

# %%
df1.plot()
# Out:
# <Axes: >

# %%
# moving average

# %%
mean_data1=df1.rolling(window=12).mean()
mean_data1.head(13)
# Out:
#             Weekly_Sales
# 2010-02-05           NaN
# 2010-02-12           NaN
# 2010-02-19           NaN
# 2010-02-26           NaN
# 2010-03-05           NaN
# 2010-03-12           NaN
# 2010-03-19           NaN
# 2010-03-26           NaN
# 2010-04-02           NaN
# 2010-04-09           NaN
# 2010-04-16           NaN
# 2010-04-23  1.514695e+06
# 2010-04-30  1.496479e+06

# %%
plt.plot(df1,color='blue')
plt.plot(mean_data1,color='red')

# %%
# before building model we should check that the data is stationary or not.if the data is non-stationary then we convert to stationary model.we can identify he non stationarity of data by using augmented dicky fuller test

# %%
# if p value <0.05 then that is stationary other wise non-stationary.
# we can make data stationary by taking log of data or differentiating the data

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result=adfuller(df1['Weekly_Sales'])
result
# Out:
# (-5.102186145192286,
#  1.3877788330759535e-05,
#  4,
#  138,
#  {'1%': -3.47864788917503,
#   '5%': -2.882721765644168,
#   '10%': -2.578065326612056},
#  3412.7325502876756)

# %%
log_data=np.log(df1)
log_data
# Out:
#             Weekly_Sales
# 2010-02-05     14.312455
# 2010-02-12     14.311400
# 2010-02-19     14.292966
# 2010-02-26     14.158907
# 2010-03-05     14.256862
# ...                  ...
# 2012-09-28     14.178109
# 2012-10-05     14.328805
# 2012-10-12     14.268541
# 2012-10-19     14.226340
# 2012-10-26     14.216740
#
# [143 rows x 1 columns]

# %%
log_data.plot()
# Out:
# <Axes: >

# %%
mean_log_data=log_data.rolling(window=12).mean()

# %%
plt.plot(log_data,color='blue')
plt.plot(mean_log_data,color='red')

# %%
result2=adfuller(log_data['Weekly_Sales'])
result2
# Out:
# (-5.124252129286307,
#  1.2527353486501314e-05,
#  4,
#  138,
#  {'1%': -3.47864788917503,
#   '5%': -2.882721765644168,
#   '10%': -2.578065326612056},
#  -261.401661937172)

# %%
diff_data1=df1['Weekly_Sales'].diff().dropna()

# %%
result3=adfuller(diff_data1)
result3
# Out:
# (-7.261575374002516,
#  1.676179669923014e-10,
#  7,
#  134,
#  {'1%': -3.480118600110386,
#   '5%': -2.8833618426136196,
#   '10%': -2.578407034974382},
#  3396.8250847356326)

# %%
final_data1=pd.DataFrame(diff_data1)
final_data1
# Out:
#             Weekly_Sales
# 2010-02-12      -1733.46
# 2010-02-19     -29989.27
# 2010-02-26    -202240.58
# 2010-03-05     145079.09
# 2010-03-12    -115265.09
# ...                  ...
# 2012-09-28     -69066.80
# 2012-10-05     233726.71
# 2012-10-12     -97713.16
# 2012-10-19     -65004.04
# 2012-10-26     -14409.03
#
# [142 rows x 1 columns]

# %%
final_data1.plot()
# Out:
# <Axes: >

# %%
# acf(auto correlation function) and pacf(partial auto correlation function) are used to find the order of model in arima and sarima
# arima-auto regressive integrated moving average
#sarima-seasonal auto regressive integrated moving average

# %%
from statsmodels.tsa.stattools import acf,pacf
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf_data=acf(final_data1)
pacf_data=pacf(final_data1)

# %%
plot_acf(acf_data)

# %%
plot_pacf(pacf_data,lags=10)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# apply arima model

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
final_data1.shape
# Out:
# (142, 1)

# %%
train_data=final_data1.iloc[0:130]['Weekly_Sales']
test_data=final_data1.iloc[130:]['Weekly_Sales']

# %%
final_data1[15:45]
# Out:
#             Weekly_Sales
# 2010-05-28      32407.88
# 2010-06-04     183454.76
# 2010-06-11     -72963.62
# 2010-06-18     -39277.03
# 2010-06-25     -80572.46
# 2010-07-02      69706.54
# 2010-07-09      53656.04
# 2010-07-16     -97135.26
# 2010-07-23     -63873.72
# 2010-07-30     -13078.60
# 2010-08-06     233505.18
# 2010-08-13     -97254.02
# 2010-08-20       4842.73
# 2010-08-27     -63937.57
# 2010-09-03      91020.61
# 2010-09-10     -32702.84
# 2010-09-17     -77082.02
# 2010-09-24     -78587.64
# 2010-10-01     101538.47
# 2010-10-08      54910.43
# 2010-10-15     -48830.83
# 2010-10-22    -113955.10
# 2010-10-29      38755.22
# 2010-11-05     167450.06
# 2010-11-12     -57179.79
# 2010-11-19     -10695.31
# 2010-11-26     471839.93
# 2010-12-03    -407590.33
# 2010-12-10     134580.48
# 2010-12-17     208420.67

# %%
arima=ARIMA(train_data,order=(1,0,1))
trained_model=arima.fit()

# %%
final_data1['Predicted']=trained_model.predict(start=len(train_data),end=len(final_data1)-1,dynamic=True)

# %%
final_data1.tail(15)
# Out:
#             Weekly_Sales     Predicted
# 2012-07-20     -29059.28           NaN
# 2012-07-27     -58831.05           NaN
# 2012-08-03     192012.08           NaN
# 2012-08-10     -38725.82 -26629.929798
# 2012-08-17       5458.08  -7350.720106
# 2012-08-24    -103745.67  -2079.838451
# 2012-08-31      87961.02   -638.794244
# 2012-09-07      79683.93   -244.816815
# 2012-09-14    -144338.46   -137.104495
# 2012-09-21     -11302.81   -107.656250
# 2012-09-28     -69066.80    -99.605183
# 2012-10-05     233726.71    -97.404044
# 2012-10-12     -97713.16    -96.802259
# 2012-10-19     -65004.04    -96.637732
# 2012-10-26     -14409.03    -96.592751

# %%
final_data1.plot()
# Out:
# <Axes: >

# %%
# apply sarima model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
sarima=SARIMAX(train_data,order=(1,0,1),seasonal_order=(1,0,1,12))

# %%
sarima_model=sarima.fit()

# %%
final_data1['Predicted']=sarima_model.predict(start=len(train_data),end=len(final_data1)-1,dynamic=True)

# %%
final_data1.tail(15)
# Out:
#             Weekly_Sales     Predicted
# 2012-07-20     -29059.28           NaN
# 2012-07-27     -58831.05           NaN
# 2012-08-03     192012.08           NaN
# 2012-08-10     -38725.82 -59151.722946
# 2012-08-17       5458.08  15886.040907
# 2012-08-24    -103745.67   7953.318041
# 2012-08-31      87961.02  22624.516742
# 2012-09-07      79683.93 -42832.659293
# 2012-09-14    -144338.46   6015.261632
# 2012-09-21     -11302.81  14012.886241
# 2012-09-28     -69066.80  22127.444871
# 2012-10-05     233726.71 -45366.491822
# 2012-10-12     -97713.16  18963.991598
# 2012-10-19     -65004.04  17382.813091
# 2012-10-26     -14409.03  48210.124161

# %%
final_data1.plot()
# Out:
# <Axes: >

# %%
forecasted_result=sarima_model.forecast(steps=12)

# %%
#final_data1.plot()
forecasted_result.plot()
# Out:
# <Axes: >

# %%
df2=pd.DataFrame(data[data['Store']==2])
df2
# Out:
#      Store       Date  Weekly_Sales
# 143      2 2010-02-05    2136989.46
# 144      2 2010-02-12    2137809.50
# 145      2 2010-02-19    2124451.54
# 146      2 2010-02-26    1865097.27
# 147      2 2010-03-05    1991013.13
# ..     ...        ...           ...
# 281      2 2012-09-28    1746470.56
# 282      2 2012-10-05    1998321.04
# 283      2 2012-10-12    1900745.13
# 284      2 2012-10-19    1847990.41
# 285      2 2012-10-26    1834458.35
#
# [143 rows x 3 columns]

# %%
df2.drop(columns=['Store'],inplace=True)
df2
# Out:
#           Date  Weekly_Sales
# 143 2010-02-05    2136989.46
# 144 2010-02-12    2137809.50
# 145 2010-02-19    2124451.54
# 146 2010-02-26    1865097.27
# 147 2010-03-05    1991013.13
# ..         ...           ...
# 281 2012-09-28    1746470.56
# 282 2012-10-05    1998321.04
# 283 2012-10-12    1900745.13
# 284 2012-10-19    1847990.41
# 285 2012-10-26    1834458.35
#
# [143 rows x 2 columns]

# %%
df2.set_index('Date',inplace=True)
df2
# Out:
#             Weekly_Sales
# Date
# 2010-02-05    2136989.46
# 2010-02-12    2137809.50
# 2010-02-19    2124451.54
# 2010-02-26    1865097.27
# 2010-03-05    1991013.13
# ...                  ...
# 2012-09-28    1746470.56
# 2012-10-05    1998321.04
# 2012-10-12    1900745.13
# 2012-10-19    1847990.41
# 2012-10-26    1834458.35
#
# [143 rows x 1 columns]

# %%
df2.index.name=None
df2
# Out:
#             Weekly_Sales
# 2010-02-05    2136989.46
# 2010-02-12    2137809.50
# 2010-02-19    2124451.54
# 2010-02-26    1865097.27
# 2010-03-05    1991013.13
# ...                  ...
# 2012-09-28    1746470.56
# 2012-10-05    1998321.04
# 2012-10-12    1900745.13
# 2012-10-19    1847990.41
# 2012-10-26    1834458.35
#
# [143 rows x 1 columns]

# %%
df2.plot()
# Out:
# <Axes: >

# %%
# moving average
mean_data2=df2.rolling(window=12).mean()
mean_data2.head(13)
# Out:
#             Weekly_Sales
# 2010-02-05           NaN
# 2010-02-12           NaN
# 2010-02-19           NaN
# 2010-02-26           NaN
# 2010-03-05           NaN
# 2010-03-12           NaN
# 2010-03-19           NaN
# 2010-03-26           NaN
# 2010-04-02           NaN
# 2010-04-09           NaN
# 2010-04-16           NaN
# 2010-04-23  1.971662e+06
# 2010-04-30  1.943783e+06

# %%
plt.plot(df2,color='blue')
plt.plot(mean_data2,color='red')

# %%
result_2_1=adfuller(df2['Weekly_Sales'])
result_2_1
# Out:
# (-3.708862572618915,
#  0.0039902070890662795,
#  6,
#  136,
#  {'1%': -3.4793722137854926,
#   '5%': -2.8830370378332995,
#   '10%': -2.578233635380623},
#  3512.243755386891)

# %%
log_data2=np.log(df2)
log_data2
# Out:
#             Weekly_Sales
# 2010-02-05     14.574909
# 2010-02-12     14.575292
# 2010-02-19     14.569024
# 2010-02-26     14.438824
# 2010-03-05     14.504154
# ...                  ...
# 2012-09-28     14.373107
# 2012-10-05     14.507818
# 2012-10-12     14.457757
# 2012-10-19     14.429609
# 2012-10-26     14.422260
#
# [143 rows x 1 columns]

# %%
log_data2.plot()
# Out:
# <Axes: >

# %%
mean_log_data2=log_data2.rolling(window=12).mean()

# %%
plt.plot(log_data2,color='blue')
plt.plot(mean_log_data2,color='red')

# %%
result_2_2=adfuller(log_data2['Weekly_Sales'])
result_2_2
# Out:
# (-3.7109333180853965,
#  0.003961969234201625,
#  6,
#  136,
#  {'1%': -3.4793722137854926,
#   '5%': -2.8830370378332995,
#   '10%': -2.578233635380623},
#  -242.9816118702406)

# %%
diff_data2=df2['Weekly_Sales'].diff().dropna()

# %%
result_2_3=adfuller(diff_data2)
result_2_3
# Out:
# (-8.084752204970668,
#  1.4297697159270982e-12,
#  5,
#  136,
#  {'1%': -3.4793722137854926,
#   '5%': -2.8830370378332995,
#   '10%': -2.578233635380623},
#  3496.5521402069503)

# %%
final_data2=pd.DataFrame(diff_data2)
final_data2
# Out:
#             Weekly_Sales
# 2010-02-12        820.04
# 2010-02-19     -13357.96
# 2010-02-26    -259354.27
# 2010-03-05     125915.86
# 2010-03-12       -529.35
# ...                  ...
# 2012-09-28     -82945.11
# 2012-10-05     251850.48
# 2012-10-12     -97575.91
# 2012-10-19     -52754.72
# 2012-10-26     -13532.06
#
# [142 rows x 1 columns]

# %%
final_data2.plot()
# Out:
# <Axes: >

# %%
acf_data2=acf(final_data2)
pacf_data2=pacf(final_data2)

# %%
plot_acf(acf_data2)

# %%
plot_pacf(pacf_data2,lags=10)

# %%
# apply arima model

#final_data2.shape

train_data=final_data2.iloc[0:130]['Weekly_Sales']
test_data=final_data2.iloc[130:]['Weekly_Sales']

final_data2[15:45]
# Out:
#             Weekly_Sales
# 2010-05-28      60176.79
# 2010-06-04     145426.04
# 2010-06-11     -77001.17
# 2010-06-18     -23901.80
# 2010-06-25     -61709.87
# 2010-07-02      64013.55
# 2010-07-09    -123038.02
# 2010-07-16     -35022.83
# 2010-07-23     -64162.08
# 2010-07-30      22528.45
# 2010-08-06     187663.82
# 2010-08-13     -96308.93
# 2010-08-20      68734.18
# 2010-08-27    -100494.74
# 2010-09-03      40767.60
# 2010-09-10     -65479.26
# 2010-09-17     -45225.23
# 2010-09-24     -69346.38
# 2010-10-01     102883.21
# 2010-10-08      22481.01
# 2010-10-15     -55565.95
# 2010-10-22     -56407.85
# 2010-10-29      64807.47
# 2010-11-05     136306.30
# 2010-11-12     -22248.67
# 2010-11-19      39926.43
# 2010-11-26     701986.12
# 2010-12-03    -642944.02
# 2010-12-10     362945.28
# 2010-12-17     230440.20

# %%
arima2=ARIMA(train_data,order=(1,0,1))
trained_model2=arima2.fit()

# %%
final_data2['Predicted']=trained_model2.predict(start=len(train_data),end=len(final_data2)-1,dynamic=True)

# %%
final_data2.tail(15)
# Out:
#             Weekly_Sales     Predicted
# 2012-07-20     -10408.67           NaN
# 2012-07-27     -61742.58           NaN
# 2012-08-03     188180.76           NaN
# 2012-08-10     -79384.68 -50039.617546
# 2012-08-17      61296.05 -21016.710007
# 2012-08-24     -51227.86  -9335.925080
# 2012-08-31      70295.15  -4634.785597
# 2012-09-07     -48306.23  -2742.728465
# 2012-09-14     -83970.44  -1981.236447
# 2012-09-21      14609.04  -1674.760451
# 2012-09-28     -82945.11  -1551.413740
# 2012-10-05     251850.48  -1501.770664
# 2012-10-12     -97575.91  -1481.790926
# 2012-10-19     -52754.72  -1473.749725
# 2012-10-26     -13532.06  -1470.513401

# %%
final_data2.plot()
# Out:
# <Axes: >

# %%
# apply sarima model

sarima2=SARIMAX(train_data,order=(1,0,1),seasonal_order=(1,0,1,12))

sarima_model2=sarima2.fit()

final_data2['Predicted']=sarima_model2.predict(start=len(train_data),end=len(final_data2)-1,dynamic=True)

# %%
final_data2.tail(15)
# Out:
#             Weekly_Sales     Predicted
# 2012-07-20     -10408.67           NaN
# 2012-07-27     -61742.58           NaN
# 2012-08-03     188180.76           NaN
# 2012-08-10     -79384.68 -63235.033461
# 2012-08-17      61296.05  21656.034539
# 2012-08-24     -51227.86  19922.798948
# 2012-08-31      70295.15  42735.432835
# 2012-09-07     -48306.23 -64709.538954
# 2012-09-14     -83970.44    882.466016
# 2012-09-21      14609.04  23570.618405
# 2012-09-28     -82945.11  18706.098747
# 2012-10-05     251850.48 -50708.849228
# 2012-10-12     -97575.91  31519.527047
# 2012-10-19     -52754.72  14655.582621
# 2012-10-26     -13532.06  62306.707595

# %%
final_data2.plot()
# Out:
# <Axes: >

# %%
forecasted_result2=sarima_model2.forecast(steps=12)

# %%
#final_data1.plot()
forecasted_result2.plot()
# Out:
# <Axes: >

# %%
df3=pd.DataFrame(data[data['Store']==3])
df3
# Out:
#      Store       Date  Weekly_Sales
# 286      3 2010-02-05     461622.22
# 287      3 2010-02-12     420728.96
# 288      3 2010-02-19     421642.19
# 289      3 2010-02-26     407204.86
# 290      3 2010-03-05     415202.04
# ..     ...        ...           ...
# 424      3 2012-09-28     389813.02
# 425      3 2012-10-05     443557.65
# 426      3 2012-10-12     410804.39
# 427      3 2012-10-19     424513.08
# 428      3 2012-10-26     405432.70
#
# [143 rows x 3 columns]

# %%
df3.drop(columns=['Store'],inplace=True)
df3
# Out:
#           Date  Weekly_Sales
# 286 2010-02-05     461622.22
# 287 2010-02-12     420728.96
# 288 2010-02-19     421642.19
# 289 2010-02-26     407204.86
# 290 2010-03-05     415202.04
# ..         ...           ...
# 424 2012-09-28     389813.02
# 425 2012-10-05     443557.65
# 426 2012-10-12     410804.39
# 427 2012-10-19     424513.08
# 428 2012-10-26     405432.70
#
# [143 rows x 2 columns]

# %%
df3.set_index('Date',inplace=True)
df3
# Out:
#             Weekly_Sales
# Date
# 2010-02-05     461622.22
# 2010-02-12     420728.96
# 2010-02-19     421642.19
# 2010-02-26     407204.86
# 2010-03-05     415202.04
# ...                  ...
# 2012-09-28     389813.02
# 2012-10-05     443557.65
# 2012-10-12     410804.39
# 2012-10-19     424513.08
# 2012-10-26     405432.70
#
# [143 rows x 1 columns]

# %%
df3.index.name=None
df3
# Out:
#             Weekly_Sales
# 2010-02-05     461622.22
# 2010-02-12     420728.96
# 2010-02-19     421642.19
# 2010-02-26     407204.86
# 2010-03-05     415202.04
# ...                  ...
# 2012-09-28     389813.02
# 2012-10-05     443557.65
# 2012-10-12     410804.39
# 2012-10-19     424513.08
# 2012-10-26     405432.70
#
# [143 rows x 1 columns]

# %%
df3.plot()
# Out:
# <Axes: >

# %%
# moving average
mean_data3=df3.rolling(window=12).mean()
mean_data3.head(13)
# Out:
#              Weekly_Sales
# 2010-02-05            NaN
# 2010-02-12            NaN
# 2010-02-19            NaN
# 2010-02-26            NaN
# 2010-03-05            NaN
# 2010-03-12            NaN
# 2010-03-19            NaN
# 2010-03-26            NaN
# 2010-04-02            NaN
# 2010-04-09            NaN
# 2010-04-16            NaN
# 2010-04-23  398334.450833
# 2010-04-30  389969.965000

# %%
plt.plot(df3,color='blue')
plt.plot(mean_data3,color='red')

# %%
result_3_1=adfuller(df3['Weekly_Sales'])
result_3_1
# Out:
# (-2.963867745511322,
#  0.038409261798312666,
#  6,
#  136,
#  {'1%': -3.4793722137854926,
#   '5%': -2.8830370378332995,
#   '10%': -2.578233635380623},
#  3064.8688740270823)

# %%
log_data3=np.log(df3)
log_data3
# Out:
#             Weekly_Sales
# 2010-02-05     13.042502
# 2010-02-12     12.949744
# 2010-02-19     12.951912
# 2010-02-26     12.917072
# 2010-03-05     12.936521
# ...                  ...
# 2012-09-28     12.873422
# 2012-10-05     13.002583
# 2012-10-12     12.925872
# 2012-10-19     12.958698
# 2012-10-26     12.912710
#
# [143 rows x 1 columns]

# %%
log_data3.plot()
# Out:
# <Axes: >

# %%
mean_log_data3=log_data3.rolling(window=12).mean()

plt.plot(log_data3,color='blue')
plt.plot(mean_log_data3,color='red')

# %%
result_3_2=adfuller(log_data3['Weekly_Sales'])
result_3_2
# Out:
# (-2.1763495199300515,
#  0.2149409054885686,
#  8,
#  134,
#  {'1%': -3.480118600110386,
#   '5%': -2.8833618426136196,
#   '10%': -2.578407034974382},
#  -261.47891811451234)

# %%
diff_data3=df3['Weekly_Sales'].diff().dropna()

# %%
result_3_3=adfuller(diff_data3)
result_3_3
# Out:
# (-6.919973796343376,
#  1.1531676337937947e-09,
#  7,
#  134,
#  {'1%': -3.480118600110386,
#   '5%': -2.8833618426136196,
#   '10%': -2.578407034974382},
#  3044.2365445585674)

# %%
final_data3=pd.DataFrame(diff_data3)
final_data3
# Out:
#             Weekly_Sales
# 2010-02-12     -40893.26
# 2010-02-19        913.23
# 2010-02-26     -14437.33
# 2010-03-05       7997.18
# 2010-03-12     -31001.35
# ...                  ...
# 2012-09-28     -24579.07
# 2012-10-05      53744.63
# 2012-10-12     -32753.26
# 2012-10-19      13708.69
# 2012-10-26     -19080.38
#
# [142 rows x 1 columns]

# %%
final_data3.plot()
# Out:
# <Axes: >

# %%
acf_data3=acf(final_data3)
pacf_data3=pacf(final_data3)

# %%
plot_acf(acf_data3)

# %%
plot_pacf(pacf_data3,lags=10)

# %%
# apply arima model

#final_data1.shape

train_data=final_data3.iloc[0:130]['Weekly_Sales']
test_data=final_data3.iloc[130:]['Weekly_Sales']

# %%
final_data3[15:45]
# Out:
#             Weekly_Sales
# 2010-05-28       6326.06
# 2010-06-04      46879.57
# 2010-06-11     -41951.71
# 2010-06-18       9059.76
# 2010-06-25      -6730.37
# 2010-07-02      23805.24
# 2010-07-09     -31937.54
# 2010-07-16       3514.60
# 2010-07-23        135.71
# 2010-07-30      -4909.44
# 2010-08-06      54680.71
# 2010-08-13     -63038.38
# 2010-08-20      12130.83
# 2010-08-27      10405.88
# 2010-09-03       4339.88
# 2010-09-10     -14213.00
# 2010-09-17      10803.67
# 2010-09-24      -7437.77
# 2010-10-01       3157.23
# 2010-10-08      36323.25
# 2010-10-15     -49522.96
# 2010-10-22       3311.59
# 2010-10-29       -304.24
# 2010-11-05      74583.82
# 2010-11-12     -36540.53
# 2010-11-19     -14089.71
# 2010-11-26     193022.52
# 2010-12-03     -89147.07
# 2010-12-10      -8778.74
# 2010-12-17      30517.36

# %%
arima3=ARIMA(train_data,order=(1,0,1))
trained_model3=arima3.fit()

# %%
final_data3['Predicted']=trained_model3.predict(start=len(train_data),end=len(final_data3)-1,dynamic=True)

# %%
final_data3.tail(15)
# Out:
#             Weekly_Sales   Predicted
# 2012-07-20      15511.75         NaN
# 2012-07-27     -42996.95         NaN
# 2012-08-03      30562.39         NaN
# 2012-08-10     -28178.69 -942.286135
# 2012-08-17       3107.23 -544.844319
# 2012-08-24      17530.84 -401.340729
# 2012-08-31      -3610.94 -349.526150
# 2012-09-07       -609.00 -330.817555
# 2012-09-14       -640.57 -324.062477
# 2012-09-21       6802.93 -321.623433
# 2012-09-28     -24579.07 -320.742772
# 2012-10-05      53744.63 -320.424793
# 2012-10-12     -32753.26 -320.309981
# 2012-10-19      13708.69 -320.268526
# 2012-10-26     -19080.38 -320.253558

# %%
final_data3.plot()
# Out:
# <Axes: >

# %%
# apply sarima model

sarima3=SARIMAX(train_data,order=(1,0,1),seasonal_order=(1,0,1,12))

sarima_model3=sarima3.fit()

final_data3['Predicted']=sarima_model3.predict(start=len(train_data),end=len(final_data3)-1,dynamic=True)

# %%
final_data3.tail(15)
# Out:
#             Weekly_Sales    Predicted
# 2012-07-20      15511.75          NaN
# 2012-07-27     -42996.95          NaN
# 2012-08-03      30562.39          NaN
# 2012-08-10     -28178.69  4075.610888
# 2012-08-17       3107.23 -1718.511680
# 2012-08-24      17530.84 -1305.164436
# 2012-08-31      -3610.94  -724.559055
# 2012-09-07       -609.00  2457.317872
# 2012-09-14       -640.57  2565.316613
# 2012-09-21       6802.93 -3562.747938
# 2012-09-28     -24579.07  3789.733500
# 2012-10-05      53744.63 -1041.766104
# 2012-10-12     -32753.26  -663.700614
# 2012-10-19      13708.69   907.558495
# 2012-10-26     -19080.38 -3559.232964

# %%
final_data3.plot()
# Out:
# <Axes: >

# %%
forecasted_result3=sarima_model3.forecast(steps=12)

# %%
forecasted_result3.plot()
# Out:
# <Axes: >

# %%
df4=pd.DataFrame(data[data['Store']==4])
df4
# Out:
#      Store       Date  Weekly_Sales
# 429      4 2010-02-05    2135143.87
# 430      4 2010-02-12    2188307.39
# 431      4 2010-02-19    2049860.26
# 432      4 2010-02-26    1925728.84
# 433      4 2010-03-05    1971057.44
# ..     ...        ...           ...
# 567      4 2012-09-28    2027620.23
# 568      4 2012-10-05    2209835.43
# 569      4 2012-10-12    2133026.07
# 570      4 2012-10-19    2097266.85
# 571      4 2012-10-26    2149594.46
#
# [143 rows x 3 columns]

# %%
df4.drop(columns=['Store'],inplace=True)
df4
# Out:
#           Date  Weekly_Sales
# 429 2010-02-05    2135143.87
# 430 2010-02-12    2188307.39
# 431 2010-02-19    2049860.26
# 432 2010-02-26    1925728.84
# 433 2010-03-05    1971057.44
# ..         ...           ...
# 567 2012-09-28    2027620.23
# 568 2012-10-05    2209835.43
# 569 2012-10-12    2133026.07
# 570 2012-10-19    2097266.85
# 571 2012-10-26    2149594.46
#
# [143 rows x 2 columns]

# %%
df4.set_index('Date',inplace=True)
df4
# Out:
#             Weekly_Sales
# Date
# 2010-02-05    2135143.87
# 2010-02-12    2188307.39
# 2010-02-19    2049860.26
# 2010-02-26    1925728.84
# 2010-03-05    1971057.44
# ...                  ...
# 2012-09-28    2027620.23
# 2012-10-05    2209835.43
# 2012-10-12    2133026.07
# 2012-10-19    2097266.85
# 2012-10-26    2149594.46
#
# [143 rows x 1 columns]

# %%
df4.index.name=None
df4
# Out:
#             Weekly_Sales
# 2010-02-05    2135143.87
# 2010-02-12    2188307.39
# 2010-02-19    2049860.26
# 2010-02-26    1925728.84
# 2010-03-05    1971057.44
# ...                  ...
# 2012-09-28    2027620.23
# 2012-10-05    2209835.43
# 2012-10-12    2133026.07
# 2012-10-19    2097266.85
# 2012-10-26    2149594.46
#
# [143 rows x 1 columns]

# %%
df4.plot()
# Out:
# <Axes: >

# %%
# moving average
mean_data4=df4.rolling(window=12).mean()
plt.plot(df4,color='blue')
plt.plot(mean_data4,color='red')

# %%
result_4_1=adfuller(df4['Weekly_Sales'])
result_4_1
# Out:
# (-2.8793819840147084,
#  0.047798662236698805,
#  6,
#  136,
#  {'1%': -3.4793722137854926,
#   '5%': -2.8830370378332995,
#   '10%': -2.578233635380623},
#  3534.637810757122)

# %%
log_data4=np.log(df4)
log_data4
# Out:
#             Weekly_Sales
# 2010-02-05     14.574045
# 2010-02-12     14.598639
# 2010-02-19     14.533282
# 2010-02-26     14.470815
# 2010-03-05     14.494081
# ...                  ...
# 2012-09-28     14.522373
# 2012-10-05     14.608429
# 2012-10-12     14.573052
# 2012-10-19     14.556146
# 2012-10-26     14.580790
#
# [143 rows x 1 columns]

# %%
log_data4.plot()
# Out:
# <Axes: >

# %%
mean_log_data4=log_data4.rolling(window=12).mean()
plt.plot(log_data4,color='blue')
plt.plot(mean_log_data4,color='red')

# %%
result_4_2=adfuller(log_data4['Weekly_Sales'])
result_4_2
# Out:
# (-2.1840700788916356,
#  0.21207781555577065,
#  8,
#  134,
#  {'1%': -3.480118600110386,
#   '5%': -2.8833618426136196,
#   '10%': -2.578407034974382},
#  -242.37033490793078)

# %%
diff_data4=df4['Weekly_Sales'].diff().dropna()

# %%
result_4_3=adfuller(diff_data4)
result_4_3
# Out:
# (-6.985339718455468,
#  7.995678269052226e-10,
#  7,
#  134,
#  {'1%': -3.480118600110386,
#   '5%': -2.8833618426136196,
#   '10%': -2.578407034974382},
#  3513.0867369065963)

# %%
final_data4=pd.DataFrame(diff_data4)
final_data4
# Out:
#             Weekly_Sales
# 2010-02-12      53163.52
# 2010-02-19    -138447.13
# 2010-02-26    -124131.42
# 2010-03-05      45328.60
# 2010-03-12     -76733.35
# ...                  ...
# 2012-09-28     -91818.30
# 2012-10-05     182215.20
# 2012-10-12     -76809.36
# 2012-10-19     -35759.22
# 2012-10-26      52327.61
#
# [142 rows x 1 columns]

# %%
final_data4.plot()
# Out:
# <Axes: >

# %%
acf_data4=acf(final_data4)
pacf_data4=pacf(final_data4)

# %%
plot_acf(acf_data4)

# %%
plot_pacf(pacf_data4,lags=10)

# %%
# apply arima model


train_data=final_data4.iloc[0:130]['Weekly_Sales']
test_data=final_data4.iloc[130:]['Weekly_Sales']

# %%
final_data4[15:45]
# Out:
#             Weekly_Sales
# 2010-05-28     -46218.90
# 2010-06-04      45756.88
# 2010-06-11     -32671.35
# 2010-06-18      59117.12
# 2010-06-25     -83084.40
# 2010-07-02      34685.26
# 2010-07-09     -69128.99
# 2010-07-16      86219.44
# 2010-07-23     -50000.88
# 2010-07-30     -51789.17
# 2010-08-06     111000.97
# 2010-08-13      99412.17
# 2010-08-20      -9869.66
# 2010-08-27    -148777.17
# 2010-09-03      87453.66
# 2010-09-10     -70036.77
# 2010-09-17      34138.80
# 2010-09-24     -89274.93
# 2010-10-01      32136.34
# 2010-10-08     108673.83
# 2010-10-15     -84149.76
# 2010-10-22      60264.97
# 2010-10-29       5722.94
# 2010-11-05      79782.79
# 2010-11-12     -13321.53
# 2010-11-19      98015.14
# 2010-11-26     691660.05
# 2010-12-03    -686939.28
# 2010-12-10     199974.69
# 2010-12-17     437552.28

# %%
arima4=ARIMA(train_data,order=(1,0,1))
trained_model4=arima4.fit()

# %%
final_data4['Predicted']=trained_model4.predict(start=len(train_data),end=len(final_data4)-1,dynamic=True)

# %%
final_data4.tail(15)
# Out:
#             Weekly_Sales    Predicted
# 2012-07-20      75311.08          NaN
# 2012-07-27    -126950.04          NaN
# 2012-08-03     125900.48          NaN
# 2012-08-10      18853.56  9767.092296
# 2012-08-17      90172.61  3223.503812
# 2012-08-24    -158298.62  1204.159490
# 2012-08-31     -44060.33   580.992019
# 2012-09-07      43923.37   388.683212
# 2012-09-14      -7250.12   329.336922
# 2012-09-21       1583.93   311.022721
# 2012-09-28     -91818.30   305.370979
# 2012-10-05     182215.20   303.626857
# 2012-10-12     -76809.36   303.088623
# 2012-10-19     -35759.22   302.922525
# 2012-10-26      52327.61   302.871267

# %%
final_data4.plot()
# Out:
# <Axes: >

# %%
# apply sarima model

sarima4=SARIMAX(train_data,order=(1,0,1),seasonal_order=(1,0,1,12))

sarima_model4=sarima4.fit()

final_data4['Predicted']=sarima_model4.predict(start=len(train_data),end=len(final_data4)-1,dynamic=True)

# %%
final_data4.tail(15)
# Out:
#             Weekly_Sales    Predicted
# 2012-07-20      75311.08          NaN
# 2012-07-27    -126950.04          NaN
# 2012-08-03     125900.48          NaN
# 2012-08-10      18853.56  5247.476385
# 2012-08-17      90172.61  1689.553647
# 2012-08-24    -158298.62  -124.858473
# 2012-08-31     -44060.33 -1562.188548
# 2012-09-07      43923.37  2262.365952
# 2012-09-14      -7250.12   418.238797
# 2012-09-21       1583.93  -472.912763
# 2012-09-28     -91818.30   124.765620
# 2012-10-05     182215.20  1272.313713
# 2012-10-12     -76809.36  -795.817206
# 2012-10-19     -35759.22   729.448892
# 2012-10-26      52327.61 -1459.208136

# %%
final_data4.plot()
# Out:
# <Axes: >

# %%
forecasted_result4=sarima_model4.forecast(steps=12)

# %%
forecasted_result4.plot()
# Out:
# <Axes: >

# %%
df5=pd.DataFrame(data[data['Store']==5])
df5
# Out:
#      Store       Date  Weekly_Sales
# 572      5 2010-02-05     317173.10
# 573      5 2010-02-12     311825.70
# 574      5 2010-02-19     303447.57
# 575      5 2010-02-26     270281.63
# 576      5 2010-03-05     288855.71
# ..     ...        ...           ...
# 710      5 2012-09-28     310141.68
# 711      5 2012-10-05     343048.29
# 712      5 2012-10-12     325345.41
# 713      5 2012-10-19     313358.15
# 714      5 2012-10-26     319550.77
#
# [143 rows x 3 columns]

# %%
df5.drop(columns=['Store'],inplace=True)
df5
# Out:
#           Date  Weekly_Sales
# 572 2010-02-05     317173.10
# 573 2010-02-12     311825.70
# 574 2010-02-19     303447.57
# 575 2010-02-26     270281.63
# 576 2010-03-05     288855.71
# ..         ...           ...
# 710 2012-09-28     310141.68
# 711 2012-10-05     343048.29
# 712 2012-10-12     325345.41
# 713 2012-10-19     313358.15
# 714 2012-10-26     319550.77
#
# [143 rows x 2 columns]

# %%
df5.set_index('Date',inplace=True)
df5
# Out:
#             Weekly_Sales
# Date
# 2010-02-05     317173.10
# 2010-02-12     311825.70
# 2010-02-19     303447.57
# 2010-02-26     270281.63
# 2010-03-05     288855.71
# ...                  ...
# 2012-09-28     310141.68
# 2012-10-05     343048.29
# 2012-10-12     325345.41
# 2012-10-19     313358.15
# 2012-10-26     319550.77
#
# [143 rows x 1 columns]

# %%
df5.index.name=None
df5
# Out:
#             Weekly_Sales
# 2010-02-05     317173.10
# 2010-02-12     311825.70
# 2010-02-19     303447.57
# 2010-02-26     270281.63
# 2010-03-05     288855.71
# ...                  ...
# 2012-09-28     310141.68
# 2012-10-05     343048.29
# 2012-10-12     325345.41
# 2012-10-19     313358.15
# 2012-10-26     319550.77
#
# [143 rows x 1 columns]

# %%
df5.plot()
# Out:
# <Axes: >

# %%
# moving average
mean_data5=df5.rolling(window=12).mean()

plt.plot(df5,color='blue')
plt.plot(mean_data5,color='red')

# %%
result_5_1=adfuller(df5['Weekly_Sales'])
result_5_1
# Out:
# (-4.310974424060913,
#  0.00042517056141923467,
#  4,
#  138,
#  {'1%': -3.47864788917503,
#   '5%': -2.882721765644168,
#   '10%': -2.578065326612056},
#  3038.49592982281)

# %%
log_data5=np.log(df5)
log_data5
# Out:
#             Weekly_Sales
# 2010-02-05     12.667203
# 2010-02-12     12.650200
# 2010-02-19     12.622964
# 2010-02-26     12.507220
# 2010-03-05     12.573683
# ...                  ...
# 2012-09-28     12.644785
# 2012-10-05     12.745627
# 2012-10-12     12.692643
# 2012-10-19     12.655102
# 2012-10-26     12.674671
#
# [143 rows x 1 columns]

# %%
log_data5.plot()
# Out:
# <Axes: >

# %%
mean_log_data5=log_data5.rolling(window=12).mean()

plt.plot(log_data5,color='blue')
plt.plot(mean_log_data5,color='red')

# %%
result_5_2=adfuller(log_data5['Weekly_Sales'])
result_5_2
# Out:
# (-4.3973837676290755,
#  0.00030001322730065845,
#  4,
#  138,
#  {'1%': -3.47864788917503,
#   '5%': -2.882721765644168,
#   '10%': -2.578065326612056},
#  -237.554487234853)

# %%
diff_data5=df5['Weekly_Sales'].diff().dropna()

# %%
result_5_3=adfuller(diff_data5)
result_5_3
# Out:
# (-6.932985445464545,
#  1.0722213925857675e-09,
#  7,
#  134,
#  {'1%': -3.480118600110386,
#   '5%': -2.8833618426136196,
#   '10%': -2.578407034974382},
#  3024.6853654059655)

# %%
final_data5=pd.DataFrame(diff_data5)
final_data5
# Out:
#             Weekly_Sales
# 2010-02-12      -5347.40
# 2010-02-19      -8378.13
# 2010-02-26     -33165.94
# 2010-03-05      18574.08
# 2010-03-12       8437.88
# ...                  ...
# 2012-09-28       2834.92
# 2012-10-05      32906.61
# 2012-10-12     -17702.88
# 2012-10-19     -11987.26
# 2012-10-26       6192.62
#
# [142 rows x 1 columns]

# %%
final_data5.plot()
# Out:
# <Axes: >

# %%
acf_data5=acf(final_data5)
pacf_data5=pacf(final_data5)

# %%
plot_acf(acf_data5)

# %%
plot_pacf(pacf_data5,lags=10)

# %%
# apply arima model


train_data=final_data5.iloc[0:130]['Weekly_Sales']
test_data=final_data5.iloc[130:]['Weekly_Sales']

# %%
final_data5[15:45]
# Out:
#             Weekly_Sales
# 2010-05-28       8397.62
# 2010-06-04      27812.78
# 2010-06-11     -41183.98
# 2010-06-18      17153.69
# 2010-06-25     -18538.30
# 2010-07-02      10735.97
# 2010-07-09     -14184.40
# 2010-07-16     -11107.17
# 2010-07-23      -5959.07
# 2010-07-30      -5813.60
# 2010-08-06      34113.99
# 2010-08-13     -16565.67
# 2010-08-20        728.03
# 2010-08-27       1314.37
# 2010-09-03      35278.25
# 2010-09-10     -17264.92
# 2010-09-17     -23974.43
# 2010-09-24      10572.93
# 2010-10-01      -9953.46
# 2010-10-08       7316.73
# 2010-10-15      -9813.65
# 2010-10-22       4307.07
# 2010-10-29      -6956.46
# 2010-11-05      47278.49
# 2010-11-12     -23482.94
# 2010-11-19      -4442.55
# 2010-11-26     190977.80
# 2010-12-03    -143871.73
# 2010-12-10       8320.65
# 2010-12-17      14989.66

# %%
arima5=ARIMA(train_data,order=(1,0,1))
trained_model5=arima5.fit()

# %%
final_data5['Predicted']=trained_model5.predict(start=len(train_data),end=len(final_data5)-1,dynamic=True)

# %%
final_data5.tail(15)
# Out:
#             Weekly_Sales     Predicted
# 2012-07-20       5001.48           NaN
# 2012-07-27     -14377.76           NaN
# 2012-08-03      17367.81           NaN
# 2012-08-10     -17435.47  10772.135540
# 2012-08-17       7254.48   3762.867979
# 2012-08-24       6817.18   1462.292562
# 2012-08-31      23810.65    707.199793
# 2012-09-07       6006.90    459.363932
# 2012-09-14     -50848.24    378.019472
# 2012-09-21       7506.09    351.320667
# 2012-09-28       2834.92    342.557609
# 2012-10-05      32906.61    339.681407
# 2012-10-12     -17702.88    338.737382
# 2012-10-19     -11987.26    338.427535
# 2012-10-26       6192.62    338.325837

# %%
final_data5.plot()
# Out:
# <Axes: >

# %%
# apply sarima model

sarima5=SARIMAX(train_data,order=(1,0,1),seasonal_order=(1,0,1,12))

sarima_model5=sarima5.fit()

final_data5['Predicted']=sarima_model5.predict(start=len(train_data),end=len(final_data5)-1,dynamic=True)

# %%
final_data5.tail(15)
# Out:
#             Weekly_Sales    Predicted
# 2012-07-20       5001.48          NaN
# 2012-07-27     -14377.76          NaN
# 2012-08-03      17367.81          NaN
# 2012-08-10     -17435.47  6047.544187
# 2012-08-17       7254.48  1442.581634
# 2012-08-24       6817.18  2165.294263
# 2012-08-31      23810.65  -601.858023
# 2012-09-07       6006.90 -1163.706401
# 2012-09-14     -50848.24  -468.920642
# 2012-09-21       7506.09 -1088.017647
# 2012-09-28       2834.92  1758.304459
# 2012-10-05      32906.61 -1425.827956
# 2012-10-12     -17702.88   682.483375
# 2012-10-19     -11987.26 -1615.484590
# 2012-10-26       6192.62  1544.013458

# %%
final_data5.plot()
# Out:
# <Axes: >

# %%
forecasted_result5=sarima_model5.forecast(steps=12)

# %%
forecasted_result5.plot()
# Out:
# <Axes: >
